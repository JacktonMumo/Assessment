# %%
import pandas

# %%
customer = pandas.read_csv('customerdata.csv')
customer
# Out:
#      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0        1         87073            100000                   2
# 1        2         38414             50000                   3
# 2        3         17341             50000                   7
# 3        4         40496             30000                   5
# 4        5         47437            100000                   6
# ..     ...           ...               ...                 ...
# 655    656         51108             99000                  10
# 656    657         60732             84000                  10
# 657    658         53834            145000                   8
# 658    659         80655            172000                  10
# 659    660         80150            167000                   9
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 0                    1                    1                 0
# 1                    0                   10                 9
# ...

# %%
customer.isnull().sum()
# Out:
# Sl_No                  0
# Customer Key           0
# Avg_Credit_Limit       0
# Total_Credit_Cards     0
# Total_visits_bank      0
# Total_visits_online    0
# Total_calls_made       0
# dtype: int64

# %%
array=customer.values
array
# Out:
# array([[     1,  87073, 100000, ...,      1,      1,      0],
#        [     2,  38414,  50000, ...,      0,     10,      9],
#        [     3,  17341,  50000, ...,      1,      3,      4],
#        ...,
#        [   658,  53834, 145000, ...,      1,      9,      1],
#        [   659,  80655, 172000, ...,      1,     15,      0],
#        [   660,  80150, 167000, ...,      0,     12,      2]])

# %%
x=array[0:661,2:7]
x
# Out:
# array([[100000,      2,      1,      1,      0],
#        [ 50000,      3,      0,     10,      9],
#        [ 50000,      7,      1,      3,      4],
#        ...,
#        [145000,      8,      1,      9,      1],
#        [172000,     10,      1,     15,      0],
#        [167000,      9,      0,     12,      2]])

# %%
from sklearn.cluster import KMeans as km
model=km(n_clusters=12,random_state=42)
model.fit(x)
# Out:
# KMeans(n_clusters=12, random_state=42)

# %%
groups=model.cluster_centers_
groups
# Out:
# array([[1.79912281e+04, 3.81578947e+00, 2.07017544e+00, 2.42105263e+00,
#         4.51754386e+00],
#        [1.33100000e+05, 8.90000000e+00, 6.00000000e-01, 1.17000000e+01,
#         1.20000000e+00],
#        [7.08367347e+04, 5.79591837e+00, 3.26530612e+00, 1.32653061e+00,
#         1.95918367e+00],
#        [1.01400000e+05, 8.33333333e+00, 6.00000000e-01, 9.26666667e+00,
#         1.20000000e+00],
#        [3.77307692e+04, 5.75000000e+00, 3.71153846e+00, 1.07692308e+00,
#         2.13461538e+00],
#        [7.10000000e+03, 3.62142857e+00, 2.09285714e+00, 2.41428571e+00,
#         4.94285714e+00],
#        [1.63200000e+05, 8.73333333e+00, 6.66666667e-01, 1.04666667e+01,
#         8.66666667e-01],
#        [5.95454545e+04, 5.50000000e+00, 3.11363636e+00, 9.31818182e-01,
#         2.04545455e+00],
#        [1.23602941e+04, 3.74264706e+00, 2.07352941e+00, 2.49264706e+00,
#         4.74264706e+00],
#        [1.87111111e+05, 8.33333333e+00, 4.44444444e-01, 1.16666667e+01,
# ...

# %%
clusters=pandas.DataFrame(groups,columns=['Avg_Credit_Limit','Total_Credit_Cards','Total_visits_bank','Total_visits_online','Total_calls_made'])
clusters
# Out:
#     Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 0       17991.228070            3.815789           2.070175
# 1      133100.000000            8.900000           0.600000
# 2       70836.734694            5.795918           3.265306
# 3      101400.000000            8.333333           0.600000
# 4       37730.769231            5.750000           3.711538
# 5        7100.000000            3.621429           2.092857
# 6      163200.000000            8.733333           0.666667
# 7       59545.454545            5.500000           3.113636
# 8       12360.294118            3.742647           2.073529
# 9      187111.111111            8.333333           0.444444
# 10      29363.636364            5.424242           3.515152
# 11      48534.883721            5.372093           3.255814
#
#     Total_visits_online  Total_calls_made
# 0              2.421053          4.517544
# 1             11.700000          1.200000
# 2              1.326531          1.959184
# ...

# %%
customer['group_number']=model.labels_
customer.head(10)
# Out:
#    Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0      1         87073            100000                   2
# 1      2         38414             50000                   3
# 2      3         17341             50000                   7
# 3      4         40496             30000                   5
# 4      5         47437            100000                   6
# 5      6         58634             20000                   3
# 6      7         48370            100000                   5
# 7      8         37376             15000                   3
# 8      9         82490              5000                   2
# 9     10         44770              3000                   4
#
#    Total_visits_bank  Total_visits_online  Total_calls_made  group_number
# 0                  1                    1                 0             3
# 1                  0                   10                 9            11
# ...

# %%
customer.groupby('group_number').size()
# Out:
# group_number
# 0     114
# 1      10
# 2      49
# 3      15
# 4      52
# 5     140
# 6      15
# 7      40
# 8     136
# 9       9
# 10     33
# 11     47
# dtype: int64

# %%
clusters
# group 10 Total_visits_bank (3.515152) Total_visits_online (1.090909)
# Out:
#     Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 0       17991.228070            3.815789           2.070175
# 1      133100.000000            8.900000           0.600000
# 2       70836.734694            5.795918           3.265306
# 3      101400.000000            8.333333           0.600000
# 4       37730.769231            5.750000           3.711538
# 5        7100.000000            3.621429           2.092857
# 6      163200.000000            8.733333           0.666667
# 7       59545.454545            5.500000           3.113636
# 8       12360.294118            3.742647           2.073529
# 9      187111.111111            8.333333           0.444444
# 10      29363.636364            5.424242           3.515152
# 11      48534.883721            5.372093           3.255814
#
#     Total_visits_online  Total_calls_made
# 0              2.421053          4.517544
# 1             11.700000          1.200000
# 2              1.326531          1.959184
# ...
